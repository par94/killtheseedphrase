# %% [markdown]
# ## Load and Preprocess the Image:
# 1. The image is loaded and resized to standard dimensions (1024x1024).
# 2.	Generate SHA-256 Hash of the Image: The image is converted to bytes, and a SHA-256 hash is generated.
# 3.	Generate 128 Unique 128-bit Segments: The image hash is concatenated with an incrementing counter and hashed again to produce unique 128-bit segments.
# 4.	Calculate Pixel Coordinates: Each 128-bit segment is split into two 64-bit parts, and modulo operation is used to generate coordinates.
# 5.	Extract RGB Values: The RGB values of the selected pixels are extracted.
# 6.	Concatenate RGB Values into Binary String: The RGB values are concatenated to form a binary string.
# 7.	Convert Binary String to Mnemonic Seed Phrase: The binary string is converted to a mnemonic seed phrase using BIP-39 standards.
# 8.	Derive Keys from Mnemonic Seed: The mnemonic seed is converted to a binary seed using PBKDF2, and then private and public keys are derived.

# %% [markdown]
# ### Install the libraries

# %%
# !pip3 install --upgrade pip
# !pip3 install mnemonic
# !pip3 install pillow
# !pip3 install pbkdf2
# Out:
# Requirement already satisfied: pip in /Users/antonpiskunov/Library/CloudStorage/Dropbox/Code/new_env/lib/python3.11/site-packages (24.1.1)
# Requirement already satisfied: mnemonic in /Users/antonpiskunov/Library/CloudStorage/Dropbox/Code/new_env/lib/python3.11/site-packages (0.21)
# Requirement already satisfied: pillow in /Users/antonpiskunov/Library/CloudStorage/Dropbox/Code/new_env/lib/python3.11/site-packages (10.4.0)
# Requirement already satisfied: pbkdf2 in /Users/antonpiskunov/Library/CloudStorage/Dropbox/Code/new_env/lib/python3.11/site-packages (1.3)

# %% [markdown]
# ---

# %% [markdown]
# ### Import all the libraries

# %%
import hashlib
import hmac
import binascii
from PIL import Image
from pbkdf2 import PBKDF2
import requests
import tkinter as tk
from tkinter import filedialog

# %% [markdown]
# ### Import an Image

# %%
# Function to select an image file
def select_image():
    root = tk.Tk()
    root.withdraw()  # Hide the root window
    filename = filedialog.askopenfilename(title="Select an Image", filetypes=[("Image files", "*.png *.jpg *.jpeg *.bmp")])
    root.destroy()  # Destroy the root window
    return filename

# Function to load and preprocess the image
def load_image(image_path):
    image = Image.open(image_path)
    image = image.resize((1024, 1024))  # Resize to standard dimensions
    return image

# Function to save the resized image
def save_resized_image(image, save_path):
    image.save(save_path)

# %% [markdown]
# ### Import the BIP-39 wordlist

# %%
# Function to download and save the BIP-39 wordlist to a file
def download_wordlist(url='https://raw.githubusercontent.com/bitcoin/bips/master/bip-0039/english.txt', filename='bip39_wordlist.txt'):
    response = requests.get(url)
    response.raise_for_status()  # Ensure we notice bad responses
    with open(filename, 'w') as file:
        file.write(response.text)

# Function to load the BIP-39 wordlist from a file
def load_wordlist(filename='bip39_wordlist.txt'):
    with open(filename, 'r') as file:
        wordlist = [line.strip() for line in file.readlines()]
    return wordlist

# %% [markdown]
# ### Processing

# %%
# Function to generate SHA-256 hash of the image
def image_hash(image):
    image_data = image.tobytes()
    hash_object = hashlib.sha256(image_data)
    return hash_object.hexdigest()

# Function to generate 128 unique 128-bit segments
def generate_segments(image_hash):
    segments = []
    for i in range(128):
        hash_input = image_hash + str(i)
        hash_output = hashlib.sha256(hash_input.encode()).hexdigest()
        segment = hash_output[:32]  # First 128 bits (32 hex characters)
        segments.append(segment)
    return segments

# Function to calculate pixel coordinates from 128-bit segment
def segment_to_coordinates(segment):
    x = int(segment[:16], 16) % 1024
    y = int(segment[16:], 16) % 1024
    return (x, y)

# Function to extract RGB values from selected pixels
def extract_rgb_values(image, coordinates):
    pixel_data = []
    for coord in coordinates:
        pixel = image.getpixel(coord)
        pixel_data.append(pixel)
    return pixel_data

# Function to concatenate RGB values into binary string
def concatenate_pixel_data(pixel_data):
    binary_string = ''
    for pixel in pixel_data:
        binary_string += '{:08b}{:08b}{:08b}'.format(pixel[0], pixel[1], pixel[2])
    return binary_string

# Updated function to convert binary string to mnemonic seed phrase
def binary_to_mnemonic(binary_string, wordlist):
    # Use only the first 256 bits (32 bytes) for practical purposes
    binary_segment = binary_string[:256]
    
    # Convert binary_segment to hexadecimal and calculate the SHA-256 hash
    hex_segment = hex(int(binary_segment, 2))[2:].zfill(64)
    checksum = hashlib.sha256(binascii.unhexlify(hex_segment)).hexdigest()[:1]  # First 4 bits of the hash
    
    # Convert the checksum to binary and append it to the binary segment
    checksum_binary = bin(int(checksum, 16))[2:].zfill(4)
    entropy_with_checksum = binary_segment + checksum_binary
    
    # Convert the entropy_with_checksum to words
    words = []
    for i in range(0, len(entropy_with_checksum), 11):
        index = int(entropy_with_checksum[i:i+11], 2)
        words.append(wordlist[index])
    return ' '.join(words)

# Function to derive keys from mnemonic seed
def mnemonic_to_seed(mnemonic, passphrase=''):
    salt = 'mnemonic' + passphrase
    seed = PBKDF2(mnemonic, salt, iterations=2048, macmodule=hmac, digestmodule=hashlib.sha512).read(64)
    return seed

# Function to derive private and public keys using ECDSA
def derive_keys(seed):
    private_key = hashlib.sha256(seed[:32]).hexdigest()
    # Public key derivation would normally involve elliptic curve multiplication,
    # for simplicity, we demonstrate it here with a hash
    public_key = hashlib.sha256(private_key.encode()).hexdigest()
    return private_key, public_key

# %% [markdown]
# ### Execution

# %%
# Example usage
if __name__ == "__main__":
    # Ensure the wordlist is downloaded
    download_wordlist()
    
    # Load the wordlist from the file
    wordlist = load_wordlist()
    
    # Let the user select an image
    image_path = select_image()
    if not image_path:
        print("No image selected. Exiting...")
        exit()

    image = load_image(image_path)

    # Save the resized image
    resized_image_path = "resized_image.png"  # You can choose a different path or filename
    save_resized_image(image, resized_image_path)
    print(f"Resized image saved as {resized_image_path}")
    
    img_hash = image_hash(image)
    segments = generate_segments(img_hash)
    coordinates = [segment_to_coordinates(segment) for segment in segments]
    pixel_data = extract_rgb_values(image, coordinates)
    binary_string = concatenate_pixel_data(pixel_data)
    mnemonic_seed = binary_to_mnemonic(binary_string, wordlist)
    seed = mnemonic_to_seed(mnemonic_seed)
    private_key, public_key = derive_keys(seed)
    
    print("Image:", image_path)
    print("Mnemonic Seed Phrase:", mnemonic_seed)
    print("Private Key:", private_key)
    print("Public Key:", public_key)
# Out:
# 2024-07-06 15:50:14.605 Python[3697:8486052] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# Resized image saved as resized_image.png
# Image: /Users/antonpiskunov/Pictures/Jackson Photos/IMG_6451.JPG
# Mnemonic Seed Phrase: embark present make catch way seat change clap earth road mushroom champion speak own motor song grab hill bunker bring lift mention motor achieve
# Private Key: ab3cf33a9eae186b2942da1015fae575f5823c7821093c891989dc7ed6f8b711
# Public Key: 1eabdcfe0b5e5307472d6acb10baf68e8150ff6bda688d07dce06d133075ab32

# %%
# !brew install gh
# Out:
# Running `brew update --auto-update`...
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:a5ef040e054444a0eb2cbcc1032fed14702dfbe2e55b25e609f3ce643f23c4ee
# ######################################################################### 100.0%
# ==> Pouring portable-ruby-3.3.3.el_capitan.bottle.tar.gz
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# actions-batch              haproxy@2.8                phodav
# age-plugin-se              iamb                       pkl
# ansible-creator            ingress2gateway            pnpm@8
# ansible@9                  inlyne                     podlet
# apache-flink-cdc           jnv                        policy_sentry
# appwrite                   jsontoolkit                porter
# asak                       jtbl                       poutine
# autotrace                  kconf                      prjtrellis
# awsdac                     kubecolor                  promptfoo
# basti                      kubectl-cnpg               protoc-gen-js
# batt                       kubectl-rook-ceph          pulsarctl
# beakerlib                  kubelogin                  qrtool
# beancount-language-server  kubernetes-cli@1.29        qshell
# bigquery-emulator          kubeshark                  rage
# bluez                      kubevpn                    ratchet
# bootterm                   kuto                       redict
# bpftop                     kuzu                       river
# c-blosc2                   lando-cli                  ronn-ng
# c4core                     lexido                     rtabmap
# cahute                     liblc3                     rust-parallel
# cargo-fuzz                 liborigin                  rustcat
# chainhook                  libpeas@1                  rustls-ffi
# chkbit                     libscfg                    scala@3.3
# chsrc                      libsql                     sherlock
# cloudflare-cli4            libtickit                  sigi
# cmake-language-server      libvirt-python             soapyremote
# codecov-cli                llama.cpp                  span-lite
# cotp                       llgo                       srgn
# cyctl                      llvm@17                    stripe-cli
# cyme                       logdy                      stripe-mock
# dep-tree                   lsusb-laniksj              superfile
# descope                    mactop                     sysaidmin
# dillo                      mako                       tartufo
# displayplacer              manim                      task@2
# dissent                    mantra                     taskopen
# dnsgen                     mdformat                   tenv
# dpcmd                      mdsh                       testscript
# ecs-deploy                 mihomo                     tinymist
# edgevpn                    mmdbinspect                tmt
# egctl                      morpheus                   tofuenv
# envelope                   msieve                     toipe
# erlang_ls                  mubeng                     topfew
# espeak-ng                  navidrome                  traefik@2
# fastapi                    nextdns                    typstfmt
# fern-api                   nmail                      typstyle
# ffmpeg@6                   npm-check-updates          uni-algo
# flawz                      nsync                      uutils-diffutils
# forbidden                  nvtop                      valkey
# gcc@13                     ocicl                      vedic
# geni                       oils-for-unix              vexctl
# gensio                     oj                         vfox
# git-split-diffs            openfa                     vrc-get
# gitu                       openjdk@21                 whisperkit-cli
# gnmic                      otree                      wstunnel
# go-size-analyzer           overarch                   yara-x
# godap                      parsedmarc                 yo
# gorilla-cli                pass-import                zfind
# gptscript                  pedump
# ==> New Casks
# 1password-cli@1                          font-migmix-1m
# 1password-cli@beta                       font-migmix-1p
# 1password@7                              font-migmix-2m
# 1password@beta                           font-migmix-2p
# 1password@nightly                        font-migu-1c
# ableton-live-intro@11                    font-migu-1m
# ableton-live-lite@11                     font-migu-1p
# ableton-live-standard@11                 font-migu-2m
# ableton-live-suite@10                    font-milonga
# ableton-live-suite@11                    font-miltonian
# adguard-vpn@nightly                      font-miltonian-tattoo
# adguard@nightly                          font-mina
# aerial@beta                              font-mingzat
# affinity-designer@1                      font-miniver
# affinity-photo@1                         font-miriam-libre
# affinity-publisher@1                     font-miriam-mono-clm
# airdash                                  font-mirza
# alcom                                    font-miss-fajardose
# alfred@4                                 font-mitr
# anchor-wallet                            font-mochiy-pop-one
# android-studio-preview@beta              font-mochiy-pop-p-one
# android-studio-preview@canary            font-modak
# anythingllm                              font-modern-antiqua
# apidog-europe                            font-mogra
# arctic                                   font-mohave
# arduino-ide@nightly                      font-moirai-one
# arm-performance-libraries                font-molengo
# arturia-software-center                  font-molle
# automattic-texts                         font-mona-sans
# azure-data-studio@insiders               font-monaspace
# ball                                     font-monaspace-nerd-font
# bbedit@14                                font-monda
# beyond-compare@beta                      font-monocraft
# bias-fx                                  font-monocraft-nerd-font
# blender@lts                              font-monofett
# blitz-gg                                 font-monofur-for-powerline
# boltai                                   font-monofur-nerd-font
# brave-browser@beta                       font-monoid
# brave-browser@dev                        font-monoid-nerd-font
# brave-browser@nightly                    font-monoisome
# buckets@beta                             font-monomaniac-one
# cahier                                   font-mononoki
# calibrite-profiler                       font-mononoki-nerd-font
# canon-ufrii-driver                       font-monoton
# capcut                                   font-monsieur-la-doulaise
# carbon-copy-cloner@5                     font-montaga
# carbon-copy-cloner@6                     font-montagu-slab
# charmstone                               font-montecarlo
# chatgpt                                  font-montez
# chime                                    font-montserrat
# chromedriver@beta                        font-montserrat-alternates
# clash-verge-rev                          font-montserrat-subrayada
# clearvpn                                 font-moo-lah-lah
# clion@eap                                font-mooli
# core-tunnel                              font-moon-dance
# corretto@11                              font-moul
# corretto@17                              font-moulpali
# corretto@21                              font-mountains-of-christmas
# corretto@8                               font-mouse-memoirs
# crystaldiffract                          font-mplus
# crystalviewer                            font-mplus-nerd-font
# darkmodebuddy                            font-mr-bedfort
# dash@6                                   font-mr-dafoe
# db-browser-for-sqlcipher@nightly         font-mr-de-haviland
# db-browser-for-sqlite@nightly            font-mrs-saint-delafield
# deadbeef@nightly                         font-mrs-sheppards
# defold@alpha                             font-ms-madi
# defold@beta                              font-mukta
# discord@canary                           font-mukta-mahee
# discord@development                      font-mukta-malar
# discord@ptb                              font-mukta-vaani
# dolphin@beta                             font-mukti-narrow
# dolphin@dev                              font-mulish
# dotnet-sdk@preview                       font-murecho
# dotnet@preview                           font-museo
# dropbox@beta                             font-museomoderno
# ea                                       font-my-soul
# element@nightly                          font-myanmar-sans-pro
# elephas@beta                             font-mynerve
# elgato-capture-device-utility            font-myrica
# emacs@nightly                            font-myricam
# emacs@pretest                            font-mystery-quest
# emclient@beta                            font-n-gage
# ente-auth                                font-nabla
# figma@beta                               font-namdhinggo
# firefox@beta                             font-nanum-brush-script
# firefox@cn                               font-nanum-gothic
# firefox@developer-edition                font-nanum-gothic-coding
# firefox@esr                              font-nanum-myeongjo
# firefox@nightly                          font-nanum-pen-script
# flox                                     font-narnoor
# folding-at-home@beta                     font-national-park
# font-0xproto                             font-nats
# font-0xproto-nerd-font                   font-neonderthaw
# font-3270                                font-nerko-one
# font-3270-nerd-font                      font-neucha
# font-437-plus                            font-neuton
# font-abeezee                             font-new-rocker
# font-abel                                font-new-tegomin
# font-abhaya-libre                        font-new-york
# font-aboreto                             font-news-cycle
# font-aboriginal-sans                     font-newsreader
# font-aboriginal-serif                    font-nico-moji
# font-abril-fatface                       font-niconne
# font-abyssinica-sil                      font-nikukyu
# font-academicons                         font-nimbus-sans-l
# font-aclonica                            font-niramit
# font-acme                                font-nixie-one
# font-actor                               font-nobile
# font-adamina                             font-nokora
# font-adinatha-tamil-brahmi               font-norican
# font-adlam-display                       font-nosifer
# font-adobe-blank                         font-nosifer-caps
# font-advent-pro                          font-notable
# font-afacad                              font-nothing-you-could-do
# font-african-sans                        font-noticia-text
# font-african-serif                       font-noto-color-emoji
# font-agave-nerd-font                     font-noto-color-emoji-compat-test
# font-agbalumo                            font-noto-emoji
# font-agdasima                            font-noto-kufi-arabic
# font-aguafina-script                     font-noto-mono
# font-ahuramzda                           font-noto-mono-for-powerline
# font-aileron                             font-noto-music
# font-akatab                              font-noto-naskh-arabic
# font-akaya-kanadaka                      font-noto-naskh-arabic-ui
# font-akaya-telivigala                    font-noto-nastaliq-urdu
# font-akronim                             font-noto-nerd-font
# font-aksara-bali-galang                  font-noto-rashi-hebrew
# font-akshar                              font-noto-sans
# font-aladin                              font-noto-sans-adlam
# font-alata                               font-noto-sans-adlam-unjoined
# font-alatsi                              font-noto-sans-anatolian-hieroglyphs
# font-albert-sans                         font-noto-sans-arabic
# font-albertella                          font-noto-sans-arabic-ui
# font-aldrich                             font-noto-sans-armenian
# font-alef                                font-noto-sans-avestan
# font-alegreya                            font-noto-sans-balinese
# font-alegreya-sans                       font-noto-sans-bamum
# font-alegreya-sans-sc                    font-noto-sans-bassa-vah
# font-alegreya-sc                         font-noto-sans-batak
# font-aleo                                font-noto-sans-bengali
# font-alex-brush                          font-noto-sans-bengali-ui
# font-alexandria                          font-noto-sans-bhaiksuki
# font-alfa-slab-one                       font-noto-sans-brahmi
# font-alice                               font-noto-sans-buginese
# font-alike                               font-noto-sans-buhid
# font-alike-angular                       font-noto-sans-canadian-aboriginal
# font-alkalami                            font-noto-sans-carian
# font-alkatra                             font-noto-sans-caucasian-albanian
# font-allan                               font-noto-sans-chakma
# font-allerta                             font-noto-sans-cham
# font-allerta-stencil                     font-noto-sans-cherokee
# font-allison                             font-noto-sans-chorasmian
# font-allura                              font-noto-sans-cjk
# font-almarai                             font-noto-sans-cjk-hk
# font-almendra                            font-noto-sans-cjk-jp
# font-almendra-display                    font-noto-sans-cjk-kr
# font-almendra-sc                         font-noto-sans-cjk-sc
# font-alumni-sans                         font-noto-sans-cjk-tc
# font-alumni-sans-collegiate-one          font-noto-sans-coptic
# font-alumni-sans-collegiate-one-sc       font-noto-sans-cuneiform
# font-alumni-sans-inline-one              font-noto-sans-cypriot
# font-alumni-sans-pinstripe               font-noto-sans-cypro-minoan
# font-alumni-sans-sc                      font-noto-sans-deseret
# font-amarante                            font-noto-sans-devanagari
# font-amaranth                            font-noto-sans-devanagari-ui
# font-amatic-sc                           font-noto-sans-display
# font-amethysta                           font-noto-sans-duployan
# font-amiko                               font-noto-sans-egyptian-hieroglyphs
# font-amiri                               font-noto-sans-elbasan
# font-amiri-quran                         font-noto-sans-elymaic
# font-amita                               font-noto-sans-ethiopic
# font-amstelvar-alpha                     font-noto-sans-georgian
# font-anaheim                             font-noto-sans-glagolitic
# font-andada-pro                          font-noto-sans-gothic
# font-andagii                             font-noto-sans-grantha
# font-andale-mono                         font-noto-sans-gujarati
# font-andika                              font-noto-sans-gujarati-ui
# font-andron-scriptor-web                 font-noto-sans-gunjala-gondi
# font-anek-bangla                         font-noto-sans-gurmukhi
# font-anek-devanagari                     font-noto-sans-gurmukhi-ui
# font-anek-gujarati                       font-noto-sans-hanifi-rohingya
# font-anek-gurmukhi                       font-noto-sans-hanunoo
# font-anek-kannada                        font-noto-sans-hatran
# font-anek-latin                          font-noto-sans-hebrew
# font-anek-malayalam                      font-noto-sans-hk
# font-anek-odia                           font-noto-sans-imperial-aramaic
# font-anek-tamil                          font-noto-sans-indic-siyaq-numbers
# font-anek-telugu                         font-noto-sans-inscriptional-pahlavi
# font-angkor                              font-noto-sans-inscriptional-parthian
# font-anka-coder                          font-noto-sans-javanese
# font-annapurna-sil                       font-noto-sans-jp
# font-annie-use-your-telescope            font-noto-sans-kaithi
# font-anonymice-nerd-font                 font-noto-sans-kannada
# font-anonymice-powerline                 font-noto-sans-kannada-ui
# font-anonymous-pro                       font-noto-sans-kawi
# font-anta                                font-noto-sans-kayah-li
# font-antic                               font-noto-sans-kharoshthi
# font-antic-didone                        font-noto-sans-khmer
# font-antic-slab                          font-noto-sans-khmer-ui
# font-antinoou                            font-noto-sans-khojki
# font-anton                               font-noto-sans-khudawadi
# font-anton-sc                            font-noto-sans-kr
# font-antonio                             font-noto-sans-lao
# font-anuphan                             font-noto-sans-lao-looped
# font-anybody                             font-noto-sans-lao-ui
# font-aoboshi-one                         font-noto-sans-lepcha
# font-ar-one-sans                         font-noto-sans-limbu
# font-arapey                              font-noto-sans-linear-a
# font-arbutus                             font-noto-sans-linear-b
# font-arbutus-slab                        font-noto-sans-lisu
# font-architects-daughter                 font-noto-sans-lycian
# font-architype-renner                    font-noto-sans-lydian
# font-archivo                             font-noto-sans-mahajani
# font-archivo-black                       font-noto-sans-malayalam
# font-archivo-narrow                      font-noto-sans-malayalam-ui
# font-are-you-serious                     font-noto-sans-mandaic
# font-aref-ruqaa                          font-noto-sans-manichaean
# font-aref-ruqaa-ink                      font-noto-sans-marchen
# font-arial                               font-noto-sans-masaram-gondi
# font-arial-black                         font-noto-sans-math
# font-arima                               font-noto-sans-mayan-numerals
# font-arimo                               font-noto-sans-medefaidrin
# font-arimo-nerd-font                     font-noto-sans-meetei-mayek
# font-arizonia                            font-noto-sans-mende-kikakui
# font-ark-pixel-10px-monospaced           font-noto-sans-meroitic
# font-ark-pixel-10px-proportional         font-noto-sans-miao
# font-ark-pixel-12px-monospaced           font-noto-sans-modi
# font-ark-pixel-12px-proportional         font-noto-sans-mongolian
# font-ark-pixel-16px-monospaced           font-noto-sans-mono
# font-ark-pixel-16px-proportional         font-noto-sans-mono-cjk-hk
# font-armata                              font-noto-sans-mono-cjk-jp
# font-arsenal                             font-noto-sans-mono-cjk-kr
# font-arsenal-sc                          font-noto-sans-mono-cjk-sc
# font-artifika                            font-noto-sans-mono-cjk-tc
# font-arvo                                font-noto-sans-mro
# font-arya                                font-noto-sans-multani
# font-asap                                font-noto-sans-myanmar
# font-asap-condensed                      font-noto-sans-myanmar-ui
# font-asar                                font-noto-sans-n-ko
# font-asset                               font-noto-sans-nabataean
# font-assistant                           font-noto-sans-nag-mundari
# font-astloch                             font-noto-sans-nandinagari
# font-asul                                font-noto-sans-new-tai-lue
# font-athiti                              font-noto-sans-newa
# font-atkinson-hyperlegible               font-noto-sans-nko
# font-atma                                font-noto-sans-nko-unjoined
# font-atomic-age                          font-noto-sans-nushu
# font-aubrey                              font-noto-sans-ogham
# font-audiowide                           font-noto-sans-ol-chiki
# font-aurulent-sans-mono-nerd-font        font-noto-sans-old-hungarian
# font-autour-one                          font-noto-sans-old-italic
# font-average                             font-noto-sans-old-north-arabian
# font-average-mono                        font-noto-sans-old-permic
# font-average-sans                        font-noto-sans-old-persian
# font-averia-gruesa-libre                 font-noto-sans-old-sogdian
# font-averia-libre                        font-noto-sans-old-south-arabian
# font-averia-sans-libre                   font-noto-sans-old-turkic
# font-averia-serif-libre                  font-noto-sans-oriya
# font-awesome-terminal-fonts              font-noto-sans-oriya-ui
# font-azeret-mono                         font-noto-sans-osage
# font-azonix                              font-noto-sans-osmanya
# font-b612                                font-noto-sans-pahawh-hmong
# font-b612-mono                           font-noto-sans-palmyrene
# font-babylonica                          font-noto-sans-pau-cin-hau
# font-bacasime-antique                    font-noto-sans-phags-pa
# font-bad-script                          font-noto-sans-phagspa
# font-bagel-fat-one                       font-noto-sans-phoenician
# font-bahiana                             font-noto-sans-psalter-pahlavi
# font-bahianita                           font-noto-sans-rejang
# font-bai-jamjuree                        font-noto-sans-runic
# font-bakbak-one                          font-noto-sans-samaritan
# font-ballet                              font-noto-sans-saurashtra
# font-baloo                               font-noto-sans-sc
# font-baloo-2                             font-noto-sans-sharada
# font-baloo-bhai-2                        font-noto-sans-shavian
# font-baloo-bhaijaan-2                    font-noto-sans-siddham
# font-baloo-bhaina-2                      font-noto-sans-signwriting
# font-baloo-chettan-2                     font-noto-sans-sinhala
# font-baloo-da-2                          font-noto-sans-sinhala-ui
# font-baloo-paaji-2                       font-noto-sans-sogdian
# font-baloo-tamma-2                       font-noto-sans-sora-sompeng
# font-baloo-tammudu-2                     font-noto-sans-soyombo
# font-baloo-thambi-2                      font-noto-sans-sundanese
# font-balsamiq-sans                       font-noto-sans-syloti-nagri
# font-balthazar                           font-noto-sans-symbols
# font-bangers                             font-noto-sans-symbols-2
# font-barlow                              font-noto-sans-syriac
# font-barlow-condensed                    font-noto-sans-syriac-eastern
# font-barlow-semi-condensed               font-noto-sans-syriac-estrangela
# font-barriecito                          font-noto-sans-syriac-western
# font-barrio                              font-noto-sans-tagalog
# font-basic                               font-noto-sans-tagbanwa
# font-baskervville                        font-noto-sans-tai-le
# font-baskervville-sc                     font-noto-sans-tai-tham
# font-batang                              font-noto-sans-tai-viet
# font-batangche                           font-noto-sans-takri
# font-battambang                          font-noto-sans-tamil
# font-baumans                             font-noto-sans-tamil-supplement
# font-bayon                               font-noto-sans-tamil-ui
# font-be-vietnam-pro                      font-noto-sans-tangsa
# font-beau-rivage                         font-noto-sans-tc
# font-bebas-neue                          font-noto-sans-telugu
# font-beiruti                             font-noto-sans-telugu-ui
# font-belanosima                          font-noto-sans-thaana
# font-belgrano                            font-noto-sans-thai
# font-bellefair                           font-noto-sans-thai-looped
# font-belleza                             font-noto-sans-thai-ui
# font-bellota                             font-noto-sans-tibetan
# font-bellota-text                        font-noto-sans-tifinagh
# font-benchnine                           font-noto-sans-tirhuta
# font-benne                               font-noto-sans-ugaritic
# font-bentham                             font-noto-sans-vai
# font-berkshire-swash                     font-noto-sans-vithkuqi
# font-besley                              font-noto-sans-wancho
# font-beth-ellen                          font-noto-sans-warang-citi
# font-bevan                               font-noto-sans-yi
# font-bhavuka                             font-noto-sans-zanabazar-square
# font-bhutuka-expanded-one                font-noto-serif
# font-big-shoulders-display               font-noto-serif-ahom
# font-big-shoulders-display-sc            font-noto-serif-armenian
# font-big-shoulders-inline-display        font-noto-serif-balinese
# font-big-shoulders-inline-display-sc     font-noto-serif-bengali
# font-big-shoulders-inline-text           font-noto-serif-cjk
# font-big-shoulders-inline-text-sc        font-noto-serif-cjk-hk
# font-big-shoulders-stencil-display       font-noto-serif-cjk-jp
# font-big-shoulders-stencil-display-sc    font-noto-serif-cjk-kr
# font-big-shoulders-stencil-text          font-noto-serif-cjk-sc
# font-big-shoulders-stencil-text-sc       font-noto-serif-cjk-tc
# font-big-shoulders-text                  font-noto-serif-devanagari
# font-big-shoulders-text-sc               font-noto-serif-display
# font-bigblue-terminal-nerd-font          font-noto-serif-dogra
# font-bigelow-rules                       font-noto-serif-ethiopic
# font-bigshot-one                         font-noto-serif-georgian
# font-bilbo                               font-noto-serif-grantha
# font-bilbo-swash-caps                    font-noto-serif-gujarati
# font-biorhyme                            font-noto-serif-gurmukhi
# font-biorhyme-expanded                   font-noto-serif-hebrew
# font-birthstone                          font-noto-serif-hentaigana
# font-birthstone-bounce                   font-noto-serif-hk
# font-biryani                             font-noto-serif-jp
# font-bitstream-vera                      font-noto-serif-kannada
# font-bitstream-vera-sans-mono-nerd-font  font-noto-serif-khitan-small-script
# font-bitter                              font-noto-serif-khmer
# font-bitter-ht                           font-noto-serif-khojki
# font-biz-udgothic                        font-noto-serif-kr
# font-biz-udmincho                        font-noto-serif-lao
# font-biz-udpgothic                       font-noto-serif-makasar
# font-biz-udpmincho                       font-noto-serif-malayalam
# font-black-and-white-picture             font-noto-serif-myanmar
# font-black-han-sans                      font-noto-serif-np-hmong
# font-black-ops-one                       font-noto-serif-nyiakeng-puachue-hmong
# font-blackout                            font-noto-serif-old-uyghur
# font-blaka                               font-noto-serif-oriya
# font-blaka-hollow                        font-noto-serif-ottoman-siyaq
# font-blaka-ink                           font-noto-serif-sc
# font-blex-mono-nerd-font                 font-noto-serif-sinhala
# font-blinker                             font-noto-serif-tamil
# font-blokk-neue                          font-noto-serif-tangut
# font-bm                                  font-noto-serif-tc
# font-bodoni-moda                         font-noto-serif-telugu
# font-bodoni-moda-sc                      font-noto-serif-thai
# font-bokor                               font-noto-serif-tibetan
# font-bona-nova                           font-noto-serif-toto
# font-bona-nova-sc                        font-noto-serif-vithkuqi
# font-bonbon                              font-noto-serif-yezidi
# font-bonheur-royale                      font-noto-traditional-nushu
# font-boogaloo                            font-noto-znamenny-musical-notation
# font-borel                               font-nova-cut
# font-bowlby-one                          font-nova-flat
# font-bowlby-one-sc                       font-nova-mono
# font-braah-one                           font-nova-oval
# font-brawler                             font-nova-round
# font-bree-serif                          font-nova-script
# font-bricolage-grotesque                 font-nova-slim
# font-briem-hand                          font-nova-square
# font-brill                               font-ntr
# font-bruno-ace                           font-numans
# font-bruno-ace-sc                        font-nunito
# font-brygada-1918                        font-nunito-sans
# font-bubblegum-sans                      font-nuosu-sil
# font-bubbler-one                         font-ocr
# font-buda                                font-odibee-sans
# font-buenard                             font-odor-mean-chey
# font-bukyvede-bold                       font-office-code-pro
# font-bukyvede-italic                     font-offside
# font-bukyvede-regular                    font-ofl-sorts-mill-goudy-tt
# font-bungee                              font-oi
# font-bungee-color                        font-ojuju
# font-bungee-hairline                     font-old-standard-tt
# font-bungee-inline                       font-oldenburg
# font-bungee-outline                      font-ole
# font-bungee-shade                        font-oleo-script
# font-bungee-spice                        font-oleo-script-swash-caps
# font-butcherman                          font-onest
# font-butterfly-kids                      font-oooh-baby
# font-cabin                               font-open-dyslexic
# font-cabin-condensed                     font-open-dyslexic-nerd-font
# font-cabin-sketch                        font-open-iconic
# font-cactus-classical-serif              font-open-sans
# font-caesar-dressing                     font-open-sans-hebrew
# font-cagliostro                          font-open-sans-hebrew-condensed
# font-cairo                               font-oppo-sans
# font-cairo-play                          font-optician-sans
# font-cal-sans                            font-oranienbaum
# font-caladea                             font-orbit
# font-calistoga                           font-orbitron
# font-calligraffitti                      font-oregano
# font-cambay                              font-orelega-one
# font-cambo                               font-orienta
# font-camingocode                         font-original-surfer
# font-candal                              font-ostrich-sans
# font-cantarell                           font-oswald
# font-cantata-one                         font-otomanopee-one
# font-cantora-one                         font-outfit
# font-caprasimo                           font-over-the-rainbow
# font-capriola                            font-overlock
# font-caramel                             font-overlock-sc
# font-carattere                           font-overpass
# font-cardo                               font-overpass-mono
# font-carlito                             font-overpass-nerd-font
# font-carme                               font-overused-grotesk
# font-carrois-gothic                      font-ovo
# font-carrois-gothic-sc                   font-oxanium
# font-carter-one                          font-oxygen
# font-cascadia-code                       font-oxygen-mono
# font-cascadia-code-nf                    font-pacifico
# font-cascadia-code-pl                    font-padauk
# font-cascadia-mono                       font-padyakke-expanded-one
# font-cascadia-mono-nf                    font-palanquin
# font-cascadia-mono-pl                    font-palanquin-dark
# font-caskaydia-cove-nerd-font            font-palemonasmufi-bold
# font-caskaydia-mono-nerd-font            font-palemonasmufi-bolditalic
# font-castoro                             font-palemonasmufi-italic
# font-castoro-titling                     font-palemonasmufi-regular
# font-catamaran                           font-palette-mosaic
# font-caudex                              font-pangolin
# font-caveat                              font-paprika
# font-caveat-brush                        font-parisienne
# font-cedarville-cursive                  font-passero-one
# font-ceviche-one                         font-passion-one
# font-chakra-petch                        font-passions-conflict
# font-changa                              font-pathway-extreme
# font-changa-one                          font-pathway-gothic-one
# font-chango                              font-patrick-hand
# font-chapbook                            font-patrick-hand-sc
# font-charis-sil                          font-pattaya
# font-charm                               font-patua-one
# font-charmonman                          font-pavanam
# font-charter                             font-paytone-one
# font-chathura                            font-peddana
# font-chau-philomene-one                  font-peralta
# font-chela-one                           font-permanent-marker
# font-chelsea-market                      font-petemoss
# font-chenla                              font-petit-formal-script
# font-chenyuluoyan                        font-petrona
# font-cherish                             font-phetsarath
# font-cherry-bomb-one                     font-philosopher
# font-cherry-cream-soda                   font-photonico-code
# font-cherry-swash                        font-phudu
# font-chewy                               font-piazzolla
# font-chiayi-city                         font-piedra
# font-chicle                              font-pigmo00
# font-chilanka                            font-pigmo01
# font-chiron-hei-hk                       font-pinyon-script
# font-chiron-sung-hk                      font-pirata-one
# font-chivo                               font-pixelify-sans
# font-chivo-mono                          font-plangothic
# font-chocolate-classical-sans            font-plaster
# font-chokokutai                          font-platypi
# font-chomsky                             font-play
# font-chonburi                            font-playball
# font-church-slavonic                     font-playfair
# font-cica                                font-playfair-display
# font-cinzel                              font-playfair-display-sc
# font-cinzel-decorative                   font-playpen-sans
# font-clear-sans                          font-playwrite-ar
# font-clicker-script                      font-playwrite-at
# font-climate-crisis                      font-playwrite-au-nsw
# font-cochineal                           font-playwrite-au-qld
# font-coda                                font-playwrite-au-sa
# font-code-new-roman-nerd-font            font-playwrite-au-tas
# font-code2002                            font-playwrite-au-vic
# font-codicon                             font-playwrite-be-vlg
# font-codystar                            font-playwrite-be-wal
# font-coelacanth                          font-playwrite-br
# font-coiny                               font-playwrite-ca
# font-combo                               font-playwrite-cl
# font-comfortaa                           font-playwrite-co
# font-comforter                           font-playwrite-cu
# font-comforter-brush                     font-playwrite-cz
# font-comic-mono                          font-playwrite-de-grund
# font-comic-neue                          font-playwrite-de-la
# font-comic-sans-ms                       font-playwrite-de-sas
# font-comic-shanns-mono-nerd-font         font-playwrite-de-va
# font-coming-soon                         font-playwrite-dk-loopet
# font-comme                               font-playwrite-dk-uloopet
# font-commissioner                        font-playwrite-es
# font-commit-mono                         font-playwrite-es-deco
# font-commit-mono-nerd-font               font-playwrite-fr-moderne
# font-computer-modern                     font-playwrite-fr-trad
# font-conakry                             font-playwrite-gb-j
# font-concert-one                         font-playwrite-gb-s
# font-condiment                           font-playwrite-hr
# font-consolas-for-powerline              font-playwrite-hr-lijeva
# font-constructium                        font-playwrite-hu
# font-content                             font-playwrite-id
# font-contrail-one                        font-playwrite-ie
# font-convergence                         font-playwrite-in
# font-cookie                              font-playwrite-is
# font-cooper-hewitt                       font-playwrite-it-moderna
# font-copse                               font-playwrite-it-trad
# font-corben                              font-playwrite-mx
# font-corinthia                           font-playwrite-ng-modern
# font-cormorant                           font-playwrite-nl
# font-cormorant-garamond                  font-playwrite-no
# font-cormorant-infant                    font-playwrite-nz
# font-cormorant-sc                        font-playwrite-pe
# font-cormorant-unicase                   font-playwrite-pl
# font-cormorant-upright                   font-playwrite-pt
# font-courgette                           font-playwrite-ro
# font-courier-new                         font-playwrite-sk
# font-courier-prime                       font-playwrite-tz
# font-courier-prime-code                  font-playwrite-us-modern
# font-courier-prime-medium-and-semi-bold  font-playwrite-us-trad
# font-courier-prime-sans                  font-playwrite-vn
# font-cousine                             font-playwrite-za
# font-cousine-nerd-font                   font-plemol-jp
# font-coustard                            font-plemol-jp-hs
# font-covered-by-your-grace               font-plemol-jp-nf
# font-cozette                             font-plus-jakarta-sans
# font-crafty-girls                        font-podkova
# font-creepster                           font-podkova-vf-beta
# font-creepster-caps                      font-poetsen-one
# font-crete-round                         font-poiret-one
# font-crimson-pro                         font-poller-one
# font-crimson-text                        font-poltawski-nowy
# font-croissant-one                       font-poly
# font-crushed                             font-pompiere
# font-cubic-11                            font-ponnala
# font-cuprum                              font-pontano-sans
# font-cute-font                           font-poor-story
# font-cutive                              font-poppins
# font-cutive-mono                         font-poppins-latin
# font-d2coding                            font-poprumcute
# font-d2coding-nerd-font                  font-port-lligat-sans
# font-daddy-time-mono-nerd-font           font-port-lligat-slab
# font-dai-banna-sil                       font-porter-sans-block
# font-damion                              font-potta-one
# font-dancing-script                      font-powerline-symbols
# font-danfo                               font-pragati-narrow
# font-dangrek                             font-praise
# font-darker-grotesque                    font-prata
# font-darumadrop-one                      font-preahvihear
# font-darwin                              font-press-start-2p
# font-dashicons                           font-pretendard
# font-david-clm                           font-pretendard-jp
# font-david-libre                         font-pretendard-std
# font-dawning-of-a-new-day                font-pridi
# font-days-one                            font-princess-sofia
# font-decovar-alpha                       font-prociono
# font-dejavu                              font-profont-nerd-font
# font-dejavu-sans-mono-for-powerline      font-profontx
# font-dejavu-sans-mono-nerd-font          font-proggy-clean-tt-nerd-font
# font-dekko                               font-prompt
# font-dela-gothic-one                     font-prosto-one
# font-delicious-handrawn                  font-protest-guerrilla
# font-delius                              font-protest-revolution
# font-delius-swash-caps                   font-protest-riot
# font-delius-unicase                      font-protest-strike
# font-della-respira                       font-proza-libre
# font-delugia-book                        font-pt-mono
# font-delugia-complete                    font-pt-sans
# font-delugia-mono-complete               font-pt-sans-caption
# font-delugia-mono-powerline              font-pt-sans-narrow
# font-delugia-powerline                   font-pt-serif
# font-denk-one                            font-pt-serif-caption
# font-devicons                            font-public-sans
# font-devonshire                          font-puppies-play
# font-dhurjati                            font-puritan
# font-dhyana                              font-purple-purse
# font-didact-gothic                       font-pushster
# font-digital-numbers                     font-qahiri
# font-digohweli-old-do                    font-quando
# font-diphylleia                          font-quantico
# font-diplomata                           font-quattrocento
# font-diplomata-sc                        font-quattrocento-sans
# font-dm-mono                             font-questrial
# font-dm-sans                             font-quicksand
# font-dm-serif-display                    font-quintessential
# font-dm-serif-text                       font-qwigley
# font-do-hyeon                            font-qwitcher-grypen
# font-dokdo                               font-racing-sans-one
# font-domine                              font-radio-canada
# font-donegal-one                         font-radio-canada-big
# font-dongle                              font-radley
# font-doppio-one                          font-rajdhani
# font-dorsa                               font-rakkas
# font-dosis                               font-raleway
# font-dotgothic16                         font-raleway-dots
# font-dotum                               font-ramabhadra
# font-dotumche                            font-ramaraja
# font-doulos-sil                          font-rambla
# font-dr-sugiyama                         font-rammetto-one
# font-dream-han-sans                      font-rampart-one
# font-droid-sans-mono-for-powerline       font-ranchers
# font-droid-sans-mono-nerd-font           font-rancho
# font-duru-sans                           font-ranga
# font-dynalight                           font-rasa
# font-dynapuff                            font-rationale
# font-eagle-lake                          font-ravi-prakash
# font-east-sea-dokdo                      font-readex-pro
# font-eater                               font-recursive
# font-eb-garamond                         font-recursive-code
# font-ebh                                 font-recursive-mono-nerd-font
# font-economica                           font-red-hat-display
# font-eczar                               font-red-hat-mono
# font-edlo                                font-red-hat-text
# font-edu-au-vic-wa-nt-hand               font-red-rose
# font-edu-nsw-act-foundation              font-redacted
# font-edu-qld-beginner                    font-redacted-script
# font-edu-sa-beginner                     font-reddit-mono
# font-edu-tas-beginner                    font-reddit-sans
# font-edu-vic-wa-nt-beginner              font-reddit-sans-condensed
# font-edwin                               font-redhat
# font-el-messiri                          font-redressed
# font-electrolize                         font-reem-kufi
# font-elice-digital-baeum                 font-reem-kufi-fun
# font-elsie                               font-reem-kufi-ink
# font-elsie-swash-caps                    font-reenie-beanie
# font-elstobd                             font-reggae-one
# font-emblema-one                         font-rem
# font-emilys-candy                        font-rethink-sans
# font-encode-sans                         font-revalia
# font-encode-sans-condensed               font-rhodium-libre
# font-encode-sans-expanded                font-ribeye
# font-encode-sans-sc                      font-ribeye-marrow
# font-encode-sans-semi-condensed          font-ricty-diminished
# font-encode-sans-semi-expanded           font-righteous
# font-engagement                          font-risque
# font-englebert                           font-road-rage
# font-enriqueta                           font-roboto
# font-envy-code-r                         font-roboto-condensed
# font-envy-code-r-nerd-font               font-roboto-flex
# font-ephesis                             font-roboto-mono
# font-epilogue                            font-roboto-mono-for-powerline
# font-erica-one                           font-roboto-mono-nerd-font
# font-escumasia                           font-roboto-serif
# font-esteban                             font-roboto-slab
# font-estonia                             font-rochester
# font-et-book                             font-rock-3d
# font-euphoria-script                     font-rock-salt
# font-everson-mono                        font-rocknroll-one
# font-ewert                               font-rokkitt
# font-exo                                 font-rokkitt-vf-beta
# font-exo-2                               font-romanesco
# font-expletus-sans                       font-ronde
# font-explora                             font-ropa-sans
# font-ezra-sil                            font-rosario
# font-fahkwang                            font-rosarivo
# font-fairfax                             font-rouge-script
# font-familjen-grotesk                    font-rounded-mplus
# font-fandol                              font-routed-gothic
# font-fantasque-sans-mono                 font-rowdies
# font-fantasque-sans-mono-nerd-font       font-rozha-one
# font-fantasque-sans-mono-noloopk         font-rubik
# font-fanwood-text                        font-rubik-80s-fade
# font-farro                               font-rubik-beastly
# font-farsan                              font-rubik-broken-fax
# font-fascinate                           font-rubik-bubbles
# font-fascinate-inline                    font-rubik-burned
# font-faster-one                          font-rubik-dirt
# font-fasthand                            font-rubik-distressed
# font-fauna-one                           font-rubik-doodle-shadow
# font-faune                               font-rubik-doodle-triangles
# font-faustina                            font-rubik-gemstones
# font-federant                            font-rubik-glitch
# font-federo                              font-rubik-glitch-pop
# font-felipa                              font-rubik-iso
# font-fenix                               font-rubik-lines
# font-festive                             font-rubik-maps
# font-figtree                             font-rubik-marker-hatch
# font-finger-paint                        font-rubik-maze
# font-finlandica                          font-rubik-microbe
# font-fira-code                           font-rubik-mono-one
# font-fira-code-nerd-font                 font-rubik-moonrocks
# font-fira-mono                           font-rubik-one
# font-fira-mono-for-powerline             font-rubik-pixels
# font-fira-mono-nerd-font                 font-rubik-puddles
# font-fira-sans                           font-rubik-scribble
# font-fira-sans-condensed                 font-rubik-spray-paint
# font-fira-sans-extra-condensed           font-rubik-storm
# font-firago                              font-rubik-vinyl
# font-firge                               font-rubik-wet-paint
# font-firgenerd                           font-ruda
# font-fjalla-one                          font-rufina
# font-fjord-one                           font-ruge-boogie
# font-flamenco                            font-ruluko
# font-flavors                             font-rum-raisin
# font-fleur-de-leah                       font-ruslan-display
# font-flow-block                          font-russo-one
# font-flow-circular                       font-ruthie
# font-flow-rounded                        font-ruwudu
# font-foldit                              font-rye
# font-fondamento                          font-sacramento
# font-fontawesome                         font-sahitya
# font-fontdiner-swanky                    font-sail
# font-forum                               font-saira
# font-foundation-icons                    font-saira-condensed
# font-foundry-sterling                    font-saira-extra-condensed
# font-fragment-mono                       font-saira-semi-condensed
# font-fragment-mono-sc                    font-saira-stencil-one
# font-francois-one                        font-salsa
# font-frank-ruhl-libre                    font-sanchez
# font-fraunces                            font-sancreek
# font-freckle-face                        font-sankofa-display
# font-fredericka-the-great                font-sans-forgetica
# font-fredoka                             font-sansation
# font-free-mono-tengwar                   font-sansita
# font-freefont                            font-sansita-one
# font-freehand                            font-sansita-swashed
# font-freeman                             font-sarabun
# font-fresca                              font-sarala
# font-frijole                             font-sarasa-gothic
# font-fruktur                             font-sarina
# ...
# font-lxgw-neoxihei                       royal-tsx@beta
# font-lxgw-neozhisong                     rstudio@daily
# font-lxgw-wenkai                         safari-technology-preview
# font-lxgw-wenkai-gb                      screaming-frog-log-file-analyser
# font-lxgw-wenkai-lite                    screenmemory
# font-lxgw-wenkai-mono-tc                 semeru-jdk-open@11
# font-lxgw-wenkai-tc                      semeru-jdk-open@17
# font-lxgw-zhenkai                        semeru-jdk-open@21
# font-m-plus-1                            semeru-jdk-open@8
# font-m-plus-1-code                       shadow@beta
# font-m-plus-1p                           signal@beta
# font-m-plus-2                            simpletex
# font-m-plus-code-latin                   singlecrystal
# font-ma-shan-zheng                       sketch@beta
# font-macondo                             skype@preview
# font-macondo-swash-caps                  slack@beta
# font-mada                                slicer@preview
# font-madimi-one                          smcfancontrol@beta
# font-magra                               sonarr@beta
# font-maiden-orange                       sonos-s1-controller
# font-maitree                             sourcetree@beta
# font-major-mono-display                  starnet2
# font-makinas4                            stashpad
# font-mako                                steinberg-activation-manager
# font-mali                                sublime-merge@dev
# font-mallanna                            sublime-text@dev
# font-mamelon                             surge@4
# font-maname                              svp
# font-mandali                             telegram-desktop@beta
# font-manjari                             tella
# font-manrope                             temurin@11
# font-mansalva                            temurin@17
# font-manuale                             temurin@19
# font-maple                               temurin@20
# font-marcellus                           temurin@21
# font-marcellus-sc                        temurin@8
# font-marck-script                        termius@beta
# font-margarine                           threema@beta
# font-marhey                              thunderbird@beta
# font-markazi-text                        thunderbird@daily
# font-marko-one                           timelapze
# font-marmelad                            toneprint
# font-martel                              topaz-photo-ai
# font-martel-sans                         tor-browser@alpha
# font-martian-mono                        transmission@nightly
# font-martian-mono-nerd-font              tsh@13
# font-marvel                              tunnelblick@beta
# font-masinahikan                         typora@dev
# font-masinahikan-dene                    ugg
# font-mate                                utm@beta
# font-mate-sc                             vcam
# font-material-design-icons-webfont       viable
# font-material-icons                      virtualbox@6
# font-material-symbols                    virtualbox@beta
# font-maven-pro                           virtualbuddy@beta
# font-maven-pro-vf-beta                   virtualdj
# font-mclaren                             visual-studio-code@insiders
# font-mea-culpa                           vivaldi@snapshot
# font-meddon                              vlc@nightly
# font-medievalsharp                       vscodium@insiders
# font-medula-one                          warcraft-logs-uploader
# font-meera-inimai                        wd-security
# font-megrim                              weasis
# font-meie-script                         wezterm@nightly
# font-meltho                              whatsapp@beta
# font-mengshen-regular                    whatsapp@legacy
# font-menlo-for-powerline                 whoozle-android-file-transfer@nightly
# font-meow-script                         wifiman
# font-merge-one                           wine@devel
# font-merienda                            wine@staging
# font-merriweather                        wins
# font-merriweather-sans                   wljs-notebook
# font-mervale-script                      wordpresscom-studio
# font-meslo-for-powerlevel10k             xampp@7
# font-meslo-for-powerline                 xcodepilot
# font-meslo-lg                            xmind@beta
# font-meslo-lg-dz                         xnapper
# font-meslo-lg-nerd-font                  yaak
# font-metal                               yandex-music
# font-metal-mania                         yass
# font-metamorphous                        yes24-ebook
# font-metrophobic                         youlean-loudness-meter
# font-metropolis                          zed@preview
# font-miama                               zotero@beta
# font-miao-unicode                        zulu@11
# font-michroma                            zulu@17
# font-micro-5                             zulu@21
# font-micro-5-charted                     zulu@8
#
# You have 59 outdated formulae installed.
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/gh/manifests/2.52.0
# ######################################################################### 100.0%
# ==> Fetching gh
# ==> Downloading https://ghcr.io/v2/homebrew/core/gh/blobs/sha256:6e036bba9386707
# ######################################################################### 100.0%
# ==> Pouring gh--2.52.0.sonoma.bottle.tar.gz
# ==> Caveats
# Bash completion has been installed to:
#   /usr/local/etc/bash_completion.d
# ==> Summary
# 🍺  /usr/local/Cellar/gh/2.52.0: 199 files, 47.5MB
# ==> Running `brew cleanup gh`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/aom_bottle_manifest--3.8.1... (21.7KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/aom--3.8.1... (4.4MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/ca-certificates_bottle_manifest--2023-12-12... (1.8KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/ca-certificates--2023-12-12... (127.7KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/cjson_bottle_manifest--1.7.17... (8.9KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/cjson--1.7.17... (52.9KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/dav1d_bottle_manifest--1.4.0... (7.4KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/dav1d--1.4.0... (746KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/ffmpeg_bottle_manifest--6.1.1_3... (95.4KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/ffmpeg--6.1.1_3... (19.8MB)
# Removing: /usr/local/Cellar/fontconfig/2.14.2... (88 files, 2.2MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/fontconfig_bottle_manifest--2.15.0... (10.2KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/fontconfig--2.15.0... (627.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/frei0r_bottle_manifest--2.3.2... (7.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/frei0r--2.3.2... (628.2KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/gcc_bottle_manifest--13.2.0-2... (14.7KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/gcc--13.2.0... (124.5MB)
# Removing: /usr/local/Cellar/gettext/0.22.3... (2,040 files, 21.4MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/gettext_bottle_manifest--0.22.5... (10KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/gettext--0.22.5... (10.1MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/glib_bottle_manifest--2.78.4... (14.7KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/glib--2.78.4... (6.3MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/gnutls_bottle_manifest--3.8.3... (17.9KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/gnutls--3.8.3... (3MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/harfbuzz_bottle_manifest--8.3.0_1... (25.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/harfbuzz--8.3.0_1... (2.6MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/hwloc_bottle_manifest--2.10.0... (8.2KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/hwloc--2.10.0... (4.2MB)
# Removing: /usr/local/Cellar/icu4c/73.2... (268 files, 79.6MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/icu4c_bottle_manifest--74.2... (8.4KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/icu4c--74.2... (28.7MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/isl_bottle_manifest--0.26... (9.6KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/isl--0.26... (1.7MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/jpeg-turbo_bottle_manifest--3.0.1... (7.7KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/jpeg-turbo--3.0.1... (1.3MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/jpeg-xl_bottle_manifest--0.9.1... (20.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/jpeg-xl--0.9.1... (2.6MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/leptonica_bottle_manifest--1.84.1... (15.8KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/leptonica--1.84.1... (2.4MB)
# Removing: /usr/local/Cellar/libidn2/2.3.4_1... (79 files, 1003KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libidn2_bottle_manifest--2.3.7... (9KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libidn2--2.3.7... (327.1KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libmicrohttpd_bottle_manifest--1.0.0... (18.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libmicrohttpd--1.0.0... (475.1KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libmpc_bottle_manifest--1.3.1... (10.2KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libmpc--1.3.1... (148.6KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libnghttp2_bottle_manifest--1.59.0... (7.4KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libnghttp2--1.59.0... (220.1KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libpng_bottle_manifest--1.6.42... (7.9KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libpng--1.6.42... (442.4KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/librist_bottle_manifest--0.2.10... (21.0KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/librist--0.2.10... (200.6KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libsodium_bottle_manifest--1.0.19... (7.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libsodium--1.0.19... (472.6KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libssh_bottle_manifest--0.10.6... (9.3KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libssh--0.10.6... (454.0KB)
# Removing: /usr/local/Cellar/libvmaf/2.3.1... (234 files, 7.2MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libvmaf_bottle_manifest--3.0.0... (7.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libvmaf--3.0.0... (1.1MB)
# Removing: /usr/local/Cellar/libxext/1.3.5... (87 files, 427.2KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libxext_bottle_manifest--1.3.6... (11.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/libxext--1.3.6... (105.4KB)
# Removing: /usr/local/Cellar/little-cms2/2.15... (21 files, 1.3MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/little-cms2_bottle_manifest--2.16... (11.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/little-cms2--2.16... (418.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/mbedtls_bottle_manifest--3.5.2... (7.2KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/mbedtls--3.5.2... (3MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/mpdecimal_bottle_manifest--4.0.0-1... (7.7KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/mpdecimal--4.0.0... (181.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/mpfr_bottle_manifest--4.2.1... (8.0KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/mpfr--4.2.1... (1MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/mpg123_bottle_manifest--1.32.5... (7.9KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/mpg123--1.32.5... (620.4KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/numpy_bottle_manifest--1.26.4... (15.8KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/numpy--1.26.4... (10.0MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/openblas_bottle_manifest--0.3.26... (14.3KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/openblas--0.3.26... (21.7MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/openssl@3_bottle_manifest--3.2.1-1... (9.2KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/openssl@3--3.2.1... (8.6MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/openvino_bottle_manifest--2023.3.0... (19.6KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/openvino--2023.3.0... (26.1MB)
# Removing: /usr/local/Cellar/p11-kit/0.25.1... (28 files, 3.7MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/p11-kit_bottle_manifest--0.25.3... (9.6KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/p11-kit--0.25.3... (922.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/pugixml_bottle_manifest--1.14... (7.4KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/pugixml--1.14... (142.6KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/pyenv_bottle_manifest--2.3.36... (26KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/python@3.12_bottle_manifest--3.12.2_1... (23.2KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/python@3.12--3.12.2_1... (15.8MB)
# Removing: /usr/local/Cellar/rav1e/0.6.6... (14 files, 52.4MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/rav1e_bottle_manifest--0.7.1... (7.4KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/rav1e--0.7.1... (12.8MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/sdl2_bottle_manifest--2.30.0... (13.7KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/sdl2--2.30.0... (1.8MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/sqlite_bottle_manifest--3.45.1... (8.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/sqlite--3.45.1... (2.3MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/svt-av1_bottle_manifest--1.8.0-1... (7.7KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/svt-av1--1.8.0... (2.8MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/tbb_bottle_manifest--2021.11.0-1... (9KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/tbb--2021.11.0... (815.2KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/tesseract_bottle_manifest--5.3.4_1... (36.7KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/tesseract--5.3.4_1... (12.6MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/unbound_bottle_manifest--1.19.1... (13.4KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/unbound--1.19.1... (2.8MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/xz_bottle_manifest--5.4.5-1... (7.5KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/xz--5.4.5... (657KB)
# Removing: /usr/local/Cellar/zeromq/4.3.5... (84 files, 6.2MB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/zeromq_bottle_manifest--4.3.5_1... (8KB)
# Removing: /Users/antonpiskunov/Library/Caches/Homebrew/zeromq--4.3.5_1... (1.6MB)
# Removing: /Users/antonpiskunov/Library/Logs/Homebrew/python@3.12... (2 files, 2KB)
# Removing: /Users/antonpiskunov/Library/Logs/Homebrew/glib... (64B)
# Removing: /Users/antonpiskunov/Library/Logs/Homebrew/gcc... (64B)
# Removing: /Users/antonpiskunov/Library/Logs/Homebrew/fontconfig... (146.9KB)
# Removing: /Users/antonpiskunov/Library/Logs/Homebrew/openssl@3... (64B)
# Removing: /Users/antonpiskunov/Library/Logs/Homebrew/ca-certificates... (64B)
# Removing: /Users/antonpiskunov/Library/Logs/Homebrew/unbound... (64B)
# Removing: /Users/antonpiskunov/Library/Logs/Homebrew/gnutls... (64B)
# Pruned 0 symbolic links and 6 directories from /usr/local

# %% [markdown]
# # Evaluation
#
# 1. Entropy Calculation: The calculate_entropy function calculates the entropy based on the number of unique colors found in randomly selected pixels.
# 2.	Collision Resistance: The check_collision_resistance function checks if any hashes collide among a set of images.
# 3.	Brute-force Resistance: The calculate_brute_force_resistance function calculates the bits of security based on the number of possible pixel combinations.
# 4.	Statistical Randomness: The check_statistical_randomness function uses the chi-square test to verify the randomness of pixel values.

# %% [markdown]
# ## Cryptographic Evaluation of Image-Based and Traditional Seed Phrase Methods
#
# ### Objective: To compare the cryptographic robustness and strength of private keys generated using image-based methods versus traditional BIP-39 seed phrases.
#
# ### Cryptographic Logic
#
# 1.	Entropy:
# * Definition: Entropy measures the unpredictability or randomness in a system. Higher entropy indicates more randomness and better security.
# * Image-Based Method: Entropy is derived from the unique pixel values in the image. Larger images with more unique colors provide higher entropy.
# * Traditional BIP-39 Seed Phrase: Each word in the BIP-39 word list represents 11 bits of entropy. A 12-word seed phrase provides 128 bits of entropy.
# 2.	Collision Resistance:
# * Definition: Collision resistance ensures that two different inputs do not produce the same hash output.
# * Image-Based Method: The hash of the entire image data should be unique for different images.
# * Traditional BIP-39 Seed Phrase: Each seed phrase should produce a unique hash.
# 3.	Brute-force Resistance:
# * Definition: Brute-force resistance measures the difficulty of guessing a secret through exhaustive search.
# * Image-Based Method: The large number of possible pixel combinations provides high brute-force resistance.
# * Traditional BIP-39 Seed Phrase: The limited set of word combinations provides lower brute-force resistance compared to image-based methods.
# 4.	Statistical Randomness:
# * Definition: Statistical randomness tests ensure that the output does not exhibit any predictable patterns.
# * Image-Based Method: The chi-square test on pixel values helps verify the randomness of the image data.
# * Traditional BIP-39 Seed Phrase: Deterministic in nature, hence this test is not applicable.
#
# ### Implementation
#
# Steps:
#
# 1.	Generate Private Keys: Derive private keys from the seed phrases generated by both methods.
# 2.	Evaluate Cryptographic Strength: Compare entropy, collision resistance, brute-force resistance, and statistical randomness.

# %% [markdown]
# ### Import libraries

# %%
import hashlib
import os
import random
import numpy as np
from PIL import Image
from collections import defaultdict
from scipy.stats import chisquare
import requests
import math
import secrets
import mnemonic
from concurrent.futures import ThreadPoolExecutor

# %% [markdown]
# ### Image download

# %%
# URLs of the test images
image_urls = [
    "https://unsplash.com/photos/KMn4VEeEPR8/download?force=true&w=1024",
    "https://unsplash.com/photos/K_JPLwJhKdk/download?force=true&w=1024",
   # https://unsplash.com/photos/a-boat-that-is-sitting-on-the-ground-aNY0nGDcNtM
    "https://unsplash.com/photos/aNY0nGDcNtM/download?force=true&w=1024"
]

# Corresponding local file names for the downloaded images
image_filenames = ["image1.jpg", "image2.jpg", "image3.jpg"]

# Function to download images
def download_images(urls, filenames):
    for url, filename in zip(urls, filenames):
        response = requests.get(url)
        response.raise_for_status()  # Ensure we notice bad responses
        with open(filename, 'wb') as file:
            file.write(response.content)
        print(f"Downloaded {filename}")

# %%
# Function to calculate entropy for image-based method
def calculate_entropy(image_path, num_pixels=128):  # Increased number of pixels for higher accuracy
    image = Image.open(image_path).resize((1024, 1024))  # Use original 1024x1024 size
    img_data = np.array(image)
    unique_colors = set()
    for _ in range(num_pixels):
        x, y = random.randint(0, 1023), random.randint(0, 1023)
        unique_colors.add(tuple(img_data[x, y]))
    entropy = len(unique_colors) * 24
    return entropy

# Function to check collision resistance for image-based method
def check_collision_resistance(image_paths):
    hashes = defaultdict(int)
    for path in image_paths:
        image = Image.open(path).resize((1024, 1024))  # Use original 1024x1024 size
        img_hash = hashlib.sha256(image.tobytes()).hexdigest()
        hashes[img_hash] += 1
        if hashes[img_hash] > 1:
            return False, img_hash
    return True, None

# Function to calculate brute-force resistance for image-based method
def calculate_brute_force_resistance(num_pixels=128):  # Increased number of pixels for higher accuracy
    total_pixels = 1024 * 1024  # Total pixels in original 1024x1024 image
    combinations = math.comb(total_pixels, num_pixels)
    brute_force_bits = math.log2(combinations)
    return brute_force_bits

# Function to check statistical randomness for image-based method
def check_statistical_randomness(image_path, num_samples=1000):  # Increased number of samples for higher accuracy
    image = Image.open(image_path).resize((1024, 1024))  # Use original 1024x1024 size
    img_data = np.array(image)
    pixel_values = []
    for _ in range(num_samples):
        x, y = random.randint(0, 1023), random.randint(0, 1023)
        pixel_values.append(img_data[x, y][0])  # Using only the Red channel for simplicity
    observed_freq = np.bincount(pixel_values, minlength=256)
    expected_freq = np.ones(256) * num_samples / 256
    chi2_stat, p_value = chisquare(observed_freq, expected_freq)
    return chi2_stat, p_value

# Function to generate a traditional BIP-39 seed phrase
def generate_seed_phrase():
    mnemo = mnemonic.Mnemonic("english")
    entropy = secrets.token_bytes(16)  # 128 bits of entropy
    seed_phrase = mnemo.to_mnemonic(entropy)
    return seed_phrase

# Function to calculate entropy for traditional seed phrase method
def calculate_entropy_seed_phrase(seed_phrase):
    return 132

# Function to check collision resistance for traditional seed phrase method
def check_collision_resistance_seed_phrase(seed_phrases):
    hashes = defaultdict(int)
    for phrase in seed_phrases:
        phrase_hash = hashlib.sha256(phrase.encode()).hexdigest()
        hashes[phrase_hash] += 1
        if hashes[phrase_hash] > 1:
            return False, phrase_hash
    return True, None

# Function to calculate brute-force resistance for traditional seed phrase method
def calculate_brute_force_resistance_seed_phrase():
    brute_force_bits = 12 * math.log2(2048)
    return brute_force_bits

# Function to run all analyses for an image
def analyze_image(image_path):
    results = {}
    results['entropy'] = calculate_entropy(image_path)
    collision_free, colliding_hash = check_collision_resistance([image_path])
    results['collision_free'] = collision_free
    results['colliding_hash'] = colliding_hash
    results['brute_force_bits'] = calculate_brute_force_resistance()
    chi2_stat, p_value = check_statistical_randomness(image_path)
    results['chi2_stat'] = chi2_stat
    results['p_value'] = p_value
    return results

# Function to run all analyses for a seed phrase
def analyze_seed_phrase(seed_phrase):
    results = {}
    results['entropy'] = calculate_entropy_seed_phrase(seed_phrase)
    collision_free, colliding_hash = check_collision_resistance_seed_phrase([seed_phrase])
    results['collision_free'] = collision_free
    results['colliding_hash'] = colliding_hash
    results['brute_force_bits'] = calculate_brute_force_resistance_seed_phrase()
    return results

# %% [markdown]
# ### Implementation

# %%
# Example usage
if __name__ == "__main__":
    # Download the test images
    download_images(image_urls, image_filenames)
    
    # Paths to the downloaded test images
    image_paths = image_filenames

    # Analyze images in parallel
    with ThreadPoolExecutor() as executor:
        image_results = list(executor.map(analyze_image, image_paths))

    for i, image_path in enumerate(image_paths):
        results = image_results[i]
        print(f"Results for {image_path} (image-based):")
        print(f"  Entropy: {results['entropy']} bits")
        print(f"  Collision Free: {results['collision_free']}")
        if not results['collision_free']:
            print(f"  Colliding Hash: {results['colliding_hash']}")
        print(f"  Brute-force resistance: {results['brute_force_bits']} bits")
        print(f"  Chi-square statistic: {results['chi2_stat']}, p-value: {results['p_value']}")

    # Generate and analyze traditional seed phrases
    seed_phrases = [generate_seed_phrase() for _ in range(3)]
    with ThreadPoolExecutor() as executor:
        seed_phrase_results = list(executor.map(analyze_seed_phrase, seed_phrases))

    for i, seed_phrase in enumerate(seed_phrases):
        results = seed_phrase_results[i]
        print(f"Results for Seed Phrase {i+1} (traditional):")
        print(f"  Seed Phrase: {seed_phrase}")
        print(f"  Entropy: {results['entropy']} bits")
        print(f"  Collision Free: {results['collision_free']}")
        if not results['collision_free']:
            print(f"  Colliding Hash: {results['colliding_hash']}")
        print(f"  Brute-force resistance: {results['brute_force_bits']} bits")
# Out:
# Downloaded image1.jpg
# Downloaded image2.jpg
# Downloaded image3.jpg
# Results for image1.jpg (image-based):
#   Entropy: 3048 bits
#   Collision Free: True
#   Brute-force resistance: 1843.8270944632009 bits
#   Chi-square statistic: 1537.984, p-value: 5.641946164598493e-182
# Results for image2.jpg (image-based):
#   Entropy: 2904 bits
#   Collision Free: True
#   Brute-force resistance: 1843.8270944632009 bits
#   Chi-square statistic: 4997.568, p-value: 0.0
# Results for image3.jpg (image-based):
#   Entropy: 2976 bits
#   Collision Free: True
#   Brute-force resistance: 1843.8270944632009 bits
#   Chi-square statistic: 650.1759999999999, p-value: 2.345593322407705e-36
# Results for Seed Phrase 1 (traditional):
#   Seed Phrase: umbrella custom prison boss fetch spring extend great obvious prepare analyst pelican
#   Entropy: 132 bits
#   Collision Free: True
#   Brute-force resistance: 132.0 bits
# Results for Seed Phrase 2 (traditional):
#   Seed Phrase: energy weapon spray body excite rival angry twelve oppose eye absent spare
#   Entropy: 132 bits
#   Collision Free: True
#   Brute-force resistance: 132.0 bits
# Results for Seed Phrase 3 (traditional):
#   Seed Phrase: consider tiger grass impose fitness sock scan giant fork donkey erosion double
#   Entropy: 132 bits
#   Collision Free: True
#   Brute-force resistance: 132.0 bits

# %% [markdown]
# ## Overview:
#
# The comparison involves evaluating the cryptographic robustness and security of private keys generated using image-based methods versus traditional BIP-39 seed phrases. The metrics used include entropy, collision resistance, brute-force resistance, and statistical randomness.
#
# ### Image-Based Method Results
#
# Image 1:
#
# •	Entropy: 3048 bits
# •	Collision Free: True
# •	Brute-force resistance: 1843.83 bits
# •	Chi-square statistic: 1537.98, p-value: 5.64e-182
#
# Image 2:
#
# •	Entropy: 2904 bits
# •	Collision Free: True
# •	Brute-force resistance: 1843.83 bits
# •	Chi-square statistic: 4997.57, p-value: 0.0
#
# Image 3:
#
# •	Entropy: 2976 bits
# •	Collision Free: True
# •	Brute-force resistance: 1843.83 bits
# •	Chi-square statistic: 650.18, p-value: 2.35e-36
#
# Traditional Seed Phrase Method Results
#
# Seed Phrase 1:
#
# •	Seed Phrase: umbrella custom prison boss fetch spring extend great obvious prepare analyst pelican
# •	Entropy: 132 bits
# •	Collision Free: True
# •	Brute-force resistance: 132 bits
#
# Seed Phrase 2:
#
# •	Seed Phrase: energy weapon spray body excite rival angry twelve oppose eye absent spare
# •	Entropy: 132 bits
# •	Collision Free: True
# •	Brute-force resistance: 132 bits
#
# Seed Phrase 3:
#
# •	Seed Phrase: consider tiger grass impose fitness sock scan giant fork donkey erosion double
# •	Entropy: 132 bits
# •	Collision Free: True
# •	Brute-force resistance: 132 bits
#
# ### Detailed Analysis
#
# #### Entropy
#
# Definition: Entropy measures the unpredictability or randomness in a system. Higher entropy indicates more randomness and better security.
#
# •	Image-Based Method: The entropy values for the images are significantly higher (3048, 2904, and 2976 bits) compared to the traditional method. This high entropy is due to the unique pixel values in the images, providing a vast amount of randomness.
# •	Traditional Method: The entropy is fixed at 132 bits, standard for a 12-word BIP-39 seed phrase. While secure for practical purposes, it is significantly lower than the image-based method.
#
# #### Collision Resistance
#
# Definition: Collision resistance ensures that two different inputs do not produce the same hash output.
#
# •	Image-Based Method: All images are collision-free, meaning each image generates a unique hash and consequently a unique seed phrase. This demonstrates good collision resistance.
# •	Traditional Method: All seed phrases are collision-free, ensuring that each phrase generates a unique hash. This is expected given the design of BIP-39.
#
# #### Brute-force Resistance
#
# Definition: Brute-force resistance measures the difficulty of guessing a secret through exhaustive search.
#
# •	Image-Based Method: The brute-force resistance is approximately 1843.83 bits, indicating an extremely large search space for potential brute-force attacks. This is due to the vast number of possible pixel combinations in a 1024x1024 image.
# •	Traditional Method: The brute-force resistance is 132 bits, consistent with the entropy. While still secure, it is much lower than the image-based method.
#
# #### Statistical Randomness
#
# Definition: Statistical randomness tests ensure that the output does not exhibit any predictable patterns.
#
# •	Image-Based Method: The chi-square test results indicate some deviation from expected randomness. High chi-square values and extremely low p-values (close to 0) suggest that the pixel values may not be perfectly random, but the vast amount of data (large images) compensates for it in terms of security.
# •	Traditional Method: Not applicable, as BIP-39 seed phrases are deterministic and do not require a randomness test.
#
# ### Comparison and Conclusion
#
# #### Image-Based Method
#
# Advantages:
#
# •	High Entropy: Provides significantly higher entropy compared to traditional methods, indicating better security.
# •	High Brute-force Resistance: Extremely resistant to brute-force attacks due to the large number of possible combinations.
# •	Unique Hashes: Demonstrates good collision resistance with unique hashes for each image.
#
# Disadvantages:
#
# •	Statistical Randomness: Chi-square test results suggest deviations from perfect randomness, but the high entropy compensates for this.
# •	Practicality: Requires storing and processing large images, which can be cumbersome compared to text-based seed phrases.
#
# #### Traditional Seed Phrase Method (BIP-39)
#
# Advantages:
#
# •	Standardized: Widely used and accepted in the cryptocurrency community.
# •	Simplicity: Easy to generate, store, and use.
# •	Secure: 132 bits of entropy is considered secure for most practical purposes.
#
# Disadvantages:
#
# •	Lower Entropy: Lower than the image-based method, indicating potentially less randomness.
# •	Lower Brute-force Resistance: Easier to brute-force compared to the image-based method, though still extremely difficult in practice.

# %% [markdown]
# ---
